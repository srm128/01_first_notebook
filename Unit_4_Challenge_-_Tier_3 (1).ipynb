# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 

import pandas as pd
import numpy as np


# Load the pyplot collection of functions from matplotlib, as plt 

import matplotlib.pyplot as plt

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
# Checking shape
properties.shape
# Out:
# (332, 49)

# %%
# Checking head
properties.head()
# Out:
#   Unnamed: 0 City of London Barking & Dagenham       Barnet       Bexley  \
# 0        NaT      E09000001          E09000002    E09000003    E09000004
# 1 1995-01-01    91448.98487         50460.2266  93284.51832  64958.09036
# 2 1995-02-01    82202.77314        51085.77983  93190.16963  64787.92069
# 3 1995-03-01    79120.70256        51268.96956  92247.52435  64367.49344
# 4 1995-04-01    77101.20804        53133.50526  90762.87492  64277.66881
#
#          Brent      Bromley       Camden      Croydon       Ealing  ...  \
# 0    E09000005    E09000006    E09000007    E09000008    E09000009  ...
# 1  71306.56698  81671.47692  120932.8881  69158.16225  79885.89069  ...
# 2  72022.26197  81657.55944  119508.8622  68951.09542  80897.06551  ...
# 3  72015.76274  81449.31143  120282.2131  68712.44341  81379.86288  ...
# 4  72965.63094  81124.41227   120097.899  68610.04641  82188.90498  ...
#
#     NORTH WEST YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND  \
# ...

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
# Transposing date and then checking head
properties_T = properties.T
properties_T.head()
# Out:
#                           0                    1                    2    \
# Unnamed: 0                NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# City of London      E09000001          91448.98487          82202.77314
# Barking & Dagenham  E09000002           50460.2266          51085.77983
# Barnet              E09000003          93284.51832          93190.16963
# Bexley              E09000004          64958.09036          64787.92069
#
#                                     3                    4    \
# Unnamed: 0          1995-03-01 00:00:00  1995-04-01 00:00:00
# City of London              79120.70256          77101.20804
# Barking & Dagenham          51268.96956          53133.50526
# Barnet                      92247.52435          90762.87492
# Bexley                      64367.49344          64277.66881
#
#                                     5                    6    \
# Unnamed: 0          1995-05-01 00:00:00  1995-06-01 00:00:00
# ...

# %%
# Calling .index to check indices
properties_T.index
# Out:
# Index(['Unnamed: 0', 'City of London', 'Barking & Dagenham', 'Barnet',
#        'Bexley', 'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow',
#        'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth', 'Lewisham',
#        'Merton', 'Newham', 'Redbridge', 'Richmond upon Thames', 'Southwark',
#        'Sutton', 'Tower Hamlets', 'Waltham Forest', 'Wandsworth',
#        'Westminster', 'Unnamed: 34', 'Inner London', 'Outer London',
#        'Unnamed: 37', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'Unnamed: 47', 'England'],
#       dtype='object')

# %%
# We do not want the boroughs to be indeces. Instead, we want numbers. 
# Resetting index and checking head. 

properties_T = properties_T.reset_index()
properties_T.head()
# Out:
#                 index          0                    1                    2  \
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001          91448.98487          82202.77314
# 2  Barking & Dagenham  E09000002           50460.2266          51085.77983
# 3              Barnet  E09000003          93284.51832          93190.16963
# 4              Bexley  E09000004          64958.09036          64787.92069
#
#                      3                    4                    5  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1          79120.70256          77101.20804          84409.14932
# 2          51268.96956          53133.50526          53042.24852
# 3          92247.52435          90762.87492          90258.00033
# 4          64367.49344          64277.66881          63997.13588
#
#                      6                    7                    8  ...  \
# ...

# %%
# Checking out the dateframe indices. 
properties_T.index
# Out:
# RangeIndex(start=0, stop=49, step=1)

# %%
properties_T.head()
# Out:
#                 index          0                    1                    2  \
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001          91448.98487          82202.77314
# 2  Barking & Dagenham  E09000002           50460.2266          51085.77983
# 3              Barnet  E09000003          93284.51832          93190.16963
# 4              Bexley  E09000004          64958.09036          64787.92069
#
#                      3                    4                    5  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1          79120.70256          77101.20804          84409.14932
# 2          51268.96956          53133.50526          53042.24852
# 3          92247.52435          90762.87492          90258.00033
# 4          64367.49344          64277.66881          63997.13588
#
#                      6                    7                    8  ...  \
# ...

# %%
# Checking that our columns are mostly intergers. 

properties_T.columns
# Out:
# Index(['index',       0,       1,       2,       3,       4,       5,       6,
#              7,       8,
#        ...
#            322,     323,     324,     325,     326,     327,     328,     329,
#            330,     331],
#       dtype='object', length=333)

# %%
# Confirming the values of the rows at index 0. We would like to make them dates. 

properties_T.iloc[[0]]
# Out:
#         index    0                    1                    2  \
# 0  Unnamed: 0  NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
#
#                      3                    4                    5  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
#
#                      6                    7                    8  ...  \
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...
#
#                    322                  323                  324  \
# 0  2021-10-01 00:00:00  2021-11-01 00:00:00  2021-12-01 00:00:00
#
#                    325                  326                  327  \
# 0  2022-01-01 00:00:00  2022-02-01 00:00:00  2022-03-01 00:00:00
#
#                    328                  329                  330  \
# 0  2022-04-01 00:00:00  2022-05-01 00:00:00  2022-06-01 00:00:00
#
#                    331
# 0  2022-07-01 00:00:00
#
# [1 rows x 333 columns]

# %%
# Reassigning the values of the columns to that of the row index 0. 

properties_T.columns = properties_T.iloc[0]

# %%
# Checking out the head again. 
properties_T.head()
# Out:
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00  \
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001          91448.98487          82202.77314
# 2  Barking & Dagenham  E09000002           50460.2266          51085.77983
# 3              Barnet  E09000003          93284.51832          93190.16963
# 4              Bexley  E09000004          64958.09036          64787.92069
#
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1          79120.70256          77101.20804          84409.14932
# 2          51268.96956          53133.50526          53042.24852
# 3          92247.52435          90762.87492          90258.00033
# 4          64367.49344          64277.66881          63997.13588
#
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...  \
# ...

# %%
# There is no need to list the dates twice. Dropping row at index 0. 

properties_T = properties_T.drop(0)
properties_T.head()
# Out:
# 0          Unnamed: 0        NaT 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001         91448.98487         82202.77314
# 2  Barking & Dagenham  E09000002          50460.2266         51085.77983
# 3              Barnet  E09000003         93284.51832         93190.16963
# 4              Bexley  E09000004         64958.09036         64787.92069
# 5               Brent  E09000005         71306.56698         72022.26197
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1         79120.70256         77101.20804         84409.14932
# 2         51268.96956         53133.50526         53042.24852
# 3         92247.52435         90762.87492         90258.00033
# 4         64367.49344         64277.66881         63997.13588
# 5         72015.76274         72965.63094         73704.04743
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1         94900.51244         110128.0423         112329.4376  ...
# ...

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
# Renaming some columns. "Unnamed 0" to "London_Borough" and NaT to "ID".

properties_T = properties_T.rename(columns={"Unnamed: 0":"London_Borough", pd.NaT:"ID"})
properties_T.head()
# Out:
# 0      London_Borough         ID 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001         91448.98487         82202.77314
# 2  Barking & Dagenham  E09000002          50460.2266         51085.77983
# 3              Barnet  E09000003         93284.51832         93190.16963
# 4              Bexley  E09000004         64958.09036         64787.92069
# 5               Brent  E09000005         71306.56698         72022.26197
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1         79120.70256         77101.20804         84409.14932
# 2         51268.96956         53133.50526         53042.24852
# 3         92247.52435         90762.87492         90258.00033
# 4         64367.49344         64277.66881         63997.13588
# 5         72015.76274         72965.63094         73704.04743
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1         94900.51244         110128.0423         112329.4376  ...
# ...

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
# We have lots of columns. pd.melt() will help us melt those values into a single column. 

clean_properties = pd.melt(properties_T, id_vars = ["London_Borough", "ID"])

# %%
clean_properties.head()
# Out:
#        London_Borough         ID          0        value
# 0      City of London  E09000001 1995-01-01  91448.98487
# 1  Barking & Dagenham  E09000002 1995-01-01   50460.2266
# 2              Barnet  E09000003 1995-01-01  93284.51832
# 3              Bexley  E09000004 1995-01-01  64958.09036
# 4               Brent  E09000005 1995-01-01  71306.56698

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
# Renaming some columns. 0 to "Date" and "value" to "Average_price".


clean_properties = clean_properties.rename(columns = {0:"Date", "value": "Average_price"})
clean_properties.head()
# Out:
#        London_Borough         ID       Date Average_price
# 0      City of London  E09000001 1995-01-01   91448.98487
# 1  Barking & Dagenham  E09000002 1995-01-01    50460.2266
# 2              Barnet  E09000003 1995-01-01   93284.51832
# 3              Bexley  E09000004 1995-01-01   64958.09036
# 4               Brent  E09000005 1995-01-01   71306.56698

# %%
# Checking to see if we need to do type conversions. 
clean_properties.dtypes
# Out:
# London_Borough            object
# ID                        object
# Date              datetime64[ns]
# Average_price             object
# dtype: object

# %%
# Average_orice seems to be an object but we would like it to be a float. 
clean_properties["Average_price"]=pd.to_numeric(clean_properties["Average_price"])
clean_properties.dtypes
# Out:
# London_Borough            object
# ID                        object
# Date              datetime64[ns]
# Average_price            float64
# dtype: object

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month (I like "Date" more) and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
# Checking if we have an equal number of observations in the ID, Average Price, Date, and London Borough columns.
clean_properties.count()
# Out:
# London_Borough    15888
# ID                14895
# Date              15888
# Average_price     14895
# dtype: int64

# %%
# Checking out contents of the London Borough column. 
clean_properties["London_Borough"].unique()
# Out:
# array(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley',
#        'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey',
#        'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth',
#        'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster', 'Unnamed: 34',
#        'Inner London', 'Outer London', 'Unnamed: 37', 'NORTH EAST',
#        'NORTH WEST', 'YORKS & THE HUMBER', 'EAST MIDLANDS',
#        'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST',
#        'SOUTH WEST', 'Unnamed: 47', 'England'], dtype=object)

# %%
# There are several strings here that seem that do not belong. We need to see what they contain to see if we can remove them. 
clean_properties[clean_properties['London_Borough'] == "Unnamed: 34"].head()
# Out:
#     London_Borough   ID       Date  Average_price
# 33     Unnamed: 34  NaN 1995-01-01            NaN
# 81     Unnamed: 34  NaN 1995-02-01            NaN
# 129    Unnamed: 34  NaN 1995-03-01            NaN
# 177    Unnamed: 34  NaN 1995-04-01            NaN
# 225    Unnamed: 34  NaN 1995-05-01            NaN

# %%
clean_properties[clean_properties['London_Borough'] == "Unnamed: 37"].head()
# Out:
#     London_Borough   ID       Date  Average_price
# 36     Unnamed: 37  NaN 1995-01-01            NaN
# 84     Unnamed: 37  NaN 1995-02-01            NaN
# 132    Unnamed: 37  NaN 1995-03-01            NaN
# 180    Unnamed: 37  NaN 1995-04-01            NaN
# 228    Unnamed: 37  NaN 1995-05-01            NaN

# %%
# Lots of rows with NaN as their ID value. Checking that out to see what we have to delete. 
clean_properties[clean_properties['ID'].isna()]
# Out:
#       London_Borough   ID       Date  Average_price
# 33       Unnamed: 34  NaN 1995-01-01            NaN
# 36       Unnamed: 37  NaN 1995-01-01            NaN
# 46       Unnamed: 47  NaN 1995-01-01            NaN
# 81       Unnamed: 34  NaN 1995-02-01            NaN
# 84       Unnamed: 37  NaN 1995-02-01            NaN
# ...              ...  ...        ...            ...
# 15828    Unnamed: 37  NaN 2022-06-01            NaN
# 15838    Unnamed: 47  NaN 2022-06-01            NaN
# 15873    Unnamed: 34  NaN 2022-07-01            NaN
# 15876    Unnamed: 37  NaN 2022-07-01            NaN
# 15886    Unnamed: 47  NaN 2022-07-01            NaN
#
# [993 rows x 4 columns]

# %%
# Deleting rows with ID values of NaN.  
clean_properties[clean_properties['ID'].isna()]
# Out:
#       London_Borough   ID       Date  Average_price
# 33       Unnamed: 34  NaN 1995-01-01            NaN
# 36       Unnamed: 37  NaN 1995-01-01            NaN
# 46       Unnamed: 47  NaN 1995-01-01            NaN
# 81       Unnamed: 34  NaN 1995-02-01            NaN
# 84       Unnamed: 37  NaN 1995-02-01            NaN
# ...              ...  ...        ...            ...
# 15828    Unnamed: 37  NaN 2022-06-01            NaN
# 15838    Unnamed: 47  NaN 2022-06-01            NaN
# 15873    Unnamed: 34  NaN 2022-07-01            NaN
# 15876    Unnamed: 37  NaN 2022-07-01            NaN
# 15886    Unnamed: 47  NaN 2022-07-01            NaN
#
# [993 rows x 4 columns]

# %%
clean_properties = clean_properties.dropna()
clean_properties["London_Borough"].nunique()
# Out:
# 45

# %%
clean_properties.head(45)
# Out:
#           London_Borough         ID       Date  Average_price
# 0         City of London  E09000001 1995-01-01    91448.98487
# 1     Barking & Dagenham  E09000002 1995-01-01    50460.22660
# 2                 Barnet  E09000003 1995-01-01    93284.51832
# 3                 Bexley  E09000004 1995-01-01    64958.09036
# 4                  Brent  E09000005 1995-01-01    71306.56698
# 5                Bromley  E09000006 1995-01-01    81671.47692
# 6                 Camden  E09000007 1995-01-01   120932.88810
# 7                Croydon  E09000008 1995-01-01    69158.16225
# 8                 Ealing  E09000009 1995-01-01    79885.89069
# 9                Enfield  E09000010 1995-01-01    72514.69096
# 10             Greenwich  E09000011 1995-01-01    62300.10169
# 11               Hackney  E09000012 1995-01-01    61296.52637
# 12  Hammersmith & Fulham  E09000013 1995-01-01   124902.86020
# 13              Haringey  E09000014 1995-01-01    76287.56947
# ...

# %%
clean_properties.count()
# Out:
# London_Borough    14895
# ID                14895
# Date              14895
# Average_price     14895
# dtype: int64

# %%
clean_properties["London_Borough"].unique()
# Out:
# array(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley',
#        'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey',
#        'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth',
#        'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster', 'Inner London',
#        'Outer London', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'England'], dtype=object)

# %%
# There are still non-boroughs in our data. Let's remove them.
#  List of Boroughs that need to be removed: 'Inner London', 'Outer London', 
# 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER', 'EAST MIDLANDS','WEST MIDLANDS', 
# 'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST',  'SOUTH WEST', 'England'

# %%
# We will use the drop method to delete the above boroughs. 
# In order to do so, I use .set_index to make the london_Boroughs's rows callable.
# Then change it back to using .reset_index() to continue working with the data. 
clean_properties_index = clean_properties.set_index("London_Borough")
clean_properties_index
# Out:
#                            ID       Date  Average_price
# London_Borough
# City of London      E09000001 1995-01-01    91448.98487
# Barking & Dagenham  E09000002 1995-01-01    50460.22660
# Barnet              E09000003 1995-01-01    93284.51832
# Bexley              E09000004 1995-01-01    64958.09036
# Brent               E09000005 1995-01-01    71306.56698
# ...                       ...        ...            ...
# EAST OF ENGLAND     E12000006 2022-07-01   358412.90616
# LONDON              E12000007 2022-07-01   543517.18884
# SOUTH EAST          E12000008 2022-07-01   398780.97110
# SOUTH WEST          E12000009 2022-07-01   330414.06132
# England             E92000001 2022-07-01   311582.69064
#
# [14895 rows x 3 columns]

# %%
clean_properties_index = clean_properties_index.drop(labels = ['Inner London', 'Outer London', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER', 'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST',  'SOUTH WEST', 'England'], axis=0)

# %%
clean_properties = clean_properties_index.reset_index()

# %%
clean_properties.head(33)
# Out:
#           London_Borough         ID       Date  Average_price
# 0         City of London  E09000001 1995-01-01    91448.98487
# 1     Barking & Dagenham  E09000002 1995-01-01    50460.22660
# 2                 Barnet  E09000003 1995-01-01    93284.51832
# 3                 Bexley  E09000004 1995-01-01    64958.09036
# 4                  Brent  E09000005 1995-01-01    71306.56698
# 5                Bromley  E09000006 1995-01-01    81671.47692
# 6                 Camden  E09000007 1995-01-01   120932.88810
# 7                Croydon  E09000008 1995-01-01    69158.16225
# 8                 Ealing  E09000009 1995-01-01    79885.89069
# 9                Enfield  E09000010 1995-01-01    72514.69096
# 10             Greenwich  E09000011 1995-01-01    62300.10169
# 11               Hackney  E09000012 1995-01-01    61296.52637
# 12  Hammersmith & Fulham  E09000013 1995-01-01   124902.86020
# 13              Haringey  E09000014 1995-01-01    76287.56947
# ...

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month (using "Date") against Average Price?

# %%
df = clean_properties
westminster_prices = df[df["London_Borough"] == "Westminster"]
westminster_plot= westminster_prices.plot(kind="line", x="Date", y="Average_price", title= "Westminster Prices through Time")
westminster_plot.set_ylabel("Price")
westminster_plot.get_yaxis().get_major_formatter().set_scientific(False) #getting rid of scientific notation.

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
df["Year"] = df['Date'].apply(lambda t: t.year)
df.head() #checking out new column
# Out:
#        London_Borough         ID       Date  Average_price  Year
# 0      City of London  E09000001 1995-01-01    91448.98487  1995
# 1  Barking & Dagenham  E09000002 1995-01-01    50460.22660  1995
# 2              Barnet  E09000003 1995-01-01    93284.51832  1995
# 3              Bexley  E09000004 1995-01-01    64958.09036  1995
# 4               Brent  E09000005 1995-01-01    71306.56698  1995

# %%
# Calculating mean for each year. 
df_year = df.groupby(by=['London_Borough', 'Year']).mean()
df_year.head()
# Out:
#                          Average_price
# London_Borough     Year
# Barking & Dagenham 1995   51817.969390
#                    1996   51718.192690
#                    1997   55974.262309
#                    1998   60285.821083
#                    1999   65320.934441

# %%
df_year = df_year.reset_index()
df_year.head()
# Out:
#        London_Borough  Year  Average_price
# 0  Barking & Dagenham  1995   51817.969390
# 1  Barking & Dagenham  1996   51718.192690
# 2  Barking & Dagenham  1997   55974.262309
# 3  Barking & Dagenham  1998   60285.821083
# 4  Barking & Dagenham  1999   65320.934441

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
dfg = df_year
def create_price_ratio(d):
    y1998 = float(d["Average_price"][d["Year"] == 1998])
    y2018 = float(d["Average_price"][d["Year"] == 2018])
    ratio = [y2018/y1998]
    return ratio

create_price_ratio(dfg[dfg['London_Borough']=='Camden'])
# Out:
# [4.935353408884261]

# %%
price_change_1998_2018 = {}

# %%
for b in dfg["London_Borough"].unique():
    borough = dfg[dfg['London_Borough']== b]
    price_change_1998_2018[b] = create_price_ratio(borough)
    
print(price_change_1998_2018)
# Out:
# {'Barking & Dagenham': [4.89661861291754], 'Barnet': [4.358195917538044], 'Bexley': [4.248977046127877], 'Brent': [4.8945544971392865], 'Bromley': [4.094784685333876], 'Camden': [4.935353408884261], 'City of London': [5.30162037758761], 'Croydon': [4.201100280024766], 'Ealing': [4.311450902121834], 'Enfield': [4.263471583495811], 'Greenwich': [4.7630363473291935], 'Hackney': [6.198285561008663], 'Hammersmith & Fulham': [4.13779810193623], 'Haringey': [5.134624964136042], 'Harrow': [4.0591964329643195], 'Havering': [4.325230371335307], 'Hillingdon': [4.2002730803844575], 'Hounslow': [3.976409106143329], 'Islington': [4.844048012802297], 'Kensington & Chelsea': [5.082465066092464], 'Kingston upon Thames': [4.270549521484271], 'Lambeth': [4.957751163514062], 'Lewisham': [5.449221041059686], 'Merton': [4.741273313294603], 'Newham': [5.305390437201879], 'Redbridge': [4.471182006097364], 'Richmond upon Thames': [4.005161895721457], 'Southwark': [5.516485302379378], 'Sutton': [4.11852260857
# ...

# %%
df_ratios= pd.DataFrame(price_change_1998_2018)
df_ratios.head()
# Out:
#    Barking & Dagenham    Barnet    Bexley     Brent   Bromley    Camden  \
# 0            4.896619  4.358196  4.248977  4.894554  4.094785  4.935353
#
#    City of London  Croydon    Ealing   Enfield  ...    Merton   Newham  \
# 0         5.30162   4.2011  4.311451  4.263472  ...  4.741273  5.30539
#
#    Redbridge  Richmond upon Thames  Southwark    Sutton  Tower Hamlets  \
# 0   4.471182              4.005162   5.516485  4.118523       4.626701
#
#    Waltham Forest  Wandsworth  Westminster
# 0        5.834756    4.757709     5.353565
#
# [1 rows x 33 columns]

# %%
df_ratios_T = df_ratios.T
df_ratios = df_ratios_T.reset_index()
df_ratios.head()
# Out:
#                 index         0
# 0  Barking & Dagenham  4.896619
# 1              Barnet  4.358196
# 2              Bexley  4.248977
# 3               Brent  4.894554
# 4             Bromley  4.094785

# %%
df_ratios.rename(columns={'index':'Borough', 0:'1998_2018'}, inplace=True)
df_ratios.head()
# Out:
#               Borough  1998_2018
# 0  Barking & Dagenham   4.896619
# 1              Barnet   4.358196
# 2              Bexley   4.248977
# 3               Brent   4.894554
# 4             Bromley   4.094785

# %%
df_ratios_sorted = df_ratios.sort_values(by='1998_2018',ascending=False)
print(df_ratios_sorted)
# Out:
#                  Borough  1998_2018
# 11               Hackney   6.198286
# 30        Waltham Forest   5.834756
# 27             Southwark   5.516485
# 22              Lewisham   5.449221
# 32           Westminster   5.353565
# 24                Newham   5.305390
# 6         City of London   5.301620
# 13              Haringey   5.134625
# 19  Kensington & Chelsea   5.082465
# 21               Lambeth   4.957751
# 5                 Camden   4.935353
# 0     Barking & Dagenham   4.896619
# 3                  Brent   4.894554
# 18             Islington   4.844048
# 10             Greenwich   4.763036
# 31            Wandsworth   4.757709
# 23                Merton   4.741273
# 29         Tower Hamlets   4.626701
# 25             Redbridge   4.471182
# 1                 Barnet   4.358196
# 15              Havering   4.325230
# 8                 Ealing   4.311451
# 20  Kingston upon Thames   4.270550
# 9                Enfield   4.263472
# 2                 Bexley   4.248977
# ...

# %%
ax = df_ratios_sorted[['Borough','1998_2018']].plot(kind='bar',ylabel="increase_in_housing_prices_ratio")


ax.set_xticklabels(df_ratios_sorted.Borough)
# Out:
# [Text(0, 0, 'Hackney'),
#  Text(1, 0, 'Waltham Forest'),
#  Text(2, 0, 'Southwark'),
#  Text(3, 0, 'Lewisham'),
#  Text(4, 0, 'Westminster'),
#  Text(5, 0, 'Newham'),
#  Text(6, 0, 'City of London'),
#  Text(7, 0, 'Haringey'),
#  Text(8, 0, 'Kensington & Chelsea'),
#  Text(9, 0, 'Lambeth'),
#  Text(10, 0, 'Camden'),
#  Text(11, 0, 'Barking & Dagenham'),
#  Text(12, 0, 'Brent'),
#  Text(13, 0, 'Islington'),
#  Text(14, 0, 'Greenwich'),
#  Text(15, 0, 'Wandsworth'),
#  Text(16, 0, 'Merton'),
#  Text(17, 0, 'Tower Hamlets'),
#  Text(18, 0, 'Redbridge'),
#  Text(19, 0, 'Barnet'),
#  Text(20, 0, 'Havering'),
#  Text(21, 0, 'Ealing'),
#  Text(22, 0, 'Kingston upon Thames'),
#  Text(23, 0, 'Enfield'),
#  Text(24, 0, 'Bexley'),
#  Text(25, 0, 'Croydon'),
#  Text(26, 0, 'Hillingdon'),
#  Text(27, 0, 'Hammersmith & Fulham'),
#  Text(28, 0, 'Sutton'),
#  Text(29, 0, 'Bromley'),
#  Text(30, 0, 'Harrow'),
#  Text(31, 0, 'Richmond upon Thames'),
#  Text(32, 0, 'Hounslow')]

# %%
top5 = df_ratios_sorted = df_ratios.sort_values(by='1998_2018',ascending=False).head(5)
ax = top5[['Borough','1998_2018']].plot(kind='bar',ylabel="increase_in_housing_prices_ratio")
ax.set_xticklabels(top5.Borough)
# Out:
# [Text(0, 0, 'Hackney'),
#  Text(1, 0, 'Waltham Forest'),
#  Text(2, 0, 'Southwark'),
#  Text(3, 0, 'Lewisham'),
#  Text(4, 0, 'Westminster')]

# %%
# While that is the parameter the project wanted to look at, I believe we can get a better picture by exploring more with the Data:
# Two points that come to mind:
# Price difference 1998 - 2018
# Prices as of 2018

# %%
# First, let's explore the price difference from 1998 to 2018:

def create_price_diff(d):
    y1998 = int(d["Average_price"][d["Year"] == 1998])
    y2018 = int(d["Average_price"][d["Year"] == 2018])
    diff = [y2018 - y1998]
    return diff

price_diff_1998_2018 = {}
for b in dfg["London_Borough"].unique():
    borough = dfg[dfg['London_Borough']== b]
    price_diff_1998_2018[b] = create_price_diff(borough)
    
df_diff= pd.DataFrame(price_diff_1998_2018)
df_diff.head()
# Out:
#    Barking & Dagenham  Barnet  Bexley   Brent  Bromley  Camden  \
# 0              234911  410907  261971  392153   335123  671722
#
#    City of London  Croydon  Ealing  Enfield  ...  Merton  Newham  Redbridge  \
# 0          636777   282155  368707   303601  ...  404244  291351     328077
#
#    Richmond upon Thames  Southwark  Sutton  Tower Hamlets  Waltham Forest  \
# 0                489709     412830  287175         349995          365302
#
#    Wandsworth  Westminster
# 0      471243       829494
#
# [1 rows x 33 columns]

# %%
df_diff_T = df_diff.T
df_diff = df_diff_T.reset_index()
df_diff.head()
# Out:
#                 index       0
# 0  Barking & Dagenham  234911
# 1              Barnet  410907
# 2              Bexley  261971
# 3               Brent  392153
# 4             Bromley  335123

# %%
df_diff.rename(columns={'index':'Borough', 0:'1998_2018'}, inplace=True)
df_diff.head()
# Out:
#               Borough  1998_2018
# 0  Barking & Dagenham     234911
# 1              Barnet     410907
# 2              Bexley     261971
# 3               Brent     392153
# 4             Bromley     335123

# %%
df_diff_sorted = df_diff.sort_values(by='1998_2018',ascending=False)
df_diff_sorted.head(33)
# Out:
#                  Borough  1998_2018
# 19  Kensington & Chelsea    1095530
# 32           Westminster     829494
# 5                 Camden     671722
# 6         City of London     636777
# 12  Hammersmith & Fulham     550185
# 18             Islington     515676
# 26  Richmond upon Thames     489709
# 31            Wandsworth     471243
# 11               Hackney     456771
# 13              Haringey     444141
# 27             Southwark     412830
# 1                 Barnet     410907
# 21               Lambeth     408357
# 23                Merton     404244
# 3                  Brent     392153
# 20  Kingston upon Thames     380691
# 8                 Ealing     368707
# 30        Waltham Forest     365302
# 14                Harrow     351129
# 29         Tower Hamlets     349995
# 22              Lewisham     336089
# 4                Bromley     335123
# 25             Redbridge     328077
# 16            Hillingdon     312590
# 10             Greenwich     306812
# ...

# %%
ax = df_diff_sorted[['Borough','1998_2018']].plot(kind='bar',ylabel="change_in_housing_prices_ratio")
ax.set_xticklabels(df_diff_sorted.Borough)
# Out:
# [Text(0, 0, 'Kensington & Chelsea'),
#  Text(1, 0, 'Westminster'),
#  Text(2, 0, 'Camden'),
#  Text(3, 0, 'City of London'),
#  Text(4, 0, 'Hammersmith & Fulham'),
#  Text(5, 0, 'Islington'),
#  Text(6, 0, 'Richmond upon Thames'),
#  Text(7, 0, 'Wandsworth'),
#  Text(8, 0, 'Hackney'),
#  Text(9, 0, 'Haringey'),
#  Text(10, 0, 'Southwark'),
#  Text(11, 0, 'Barnet'),
#  Text(12, 0, 'Lambeth'),
#  Text(13, 0, 'Merton'),
#  Text(14, 0, 'Brent'),
#  Text(15, 0, 'Kingston upon Thames'),
#  Text(16, 0, 'Ealing'),
#  Text(17, 0, 'Waltham Forest'),
#  Text(18, 0, 'Harrow'),
#  Text(19, 0, 'Tower Hamlets'),
#  Text(20, 0, 'Lewisham'),
#  Text(21, 0, 'Bromley'),
#  Text(22, 0, 'Redbridge'),
#  Text(23, 0, 'Hillingdon'),
#  Text(24, 0, 'Greenwich'),
#  Text(25, 0, 'Enfield'),
#  Text(26, 0, 'Hounslow'),
#  Text(27, 0, 'Newham'),
#  Text(28, 0, 'Sutton'),
#  Text(29, 0, 'Havering'),
#  Text(30, 0, 'Croydon'),
#  Text(31, 0, 'Bexley'),
#  Text(32, 0, 'Barking & Dagenham')]

# %%
top5_diff = df_diff_sorted = df_diff.sort_values(by='1998_2018',ascending=False).head(5)
ax = top5_diff[['Borough','1998_2018']].plot(kind='bar',ylabel="change_housing_prices_ratio")
ax.set_xticklabels(top5_diff.Borough)
# Out:
# [Text(0, 0, 'Kensington & Chelsea'),
#  Text(1, 0, 'Westminster'),
#  Text(2, 0, 'Camden'),
#  Text(3, 0, 'City of London'),
#  Text(4, 0, 'Hammersmith & Fulham')]

# %%
# Now, let's explore the average price in 1998.

def Average_price_1998(d):
    y1998 = int(d["Average_price"][d["Year"] == 1998])
    y1998 = [y1998]
    return y1998

prices_1998={}
for b in dfg["London_Borough"].unique():
    borough = dfg[dfg['London_Borough']== b]
    prices_1998[b] = Average_price_1998(borough)

df_prices_1998 = pd.DataFrame(prices_1998)
df_prices_1998.head()
# Out:
#    Barking & Dagenham  Barnet  Bexley   Brent  Bromley  Camden  \
# 0               60285  122359   80632  100692   108286  170688
#
#    City of London  Croydon  Ealing  Enfield  ...  Merton  Newham  Redbridge  \
# 0          148031    88143  111343    93030  ...  108049   67671      94514
#
#    Richmond upon Thames  Southwark  Sutton  Tower Hamlets  Waltham Forest  \
# 0                162956      91405   92087          96505           75557
#
#    Wandsworth  Westminster
# 0      125406       190531
#
# [1 rows x 33 columns]

# %%
df_prices_1998_T = df_prices_1998.T
df_prices_1998 = df_prices_1998_T.reset_index()
df_prices_1998.head()
# Out:
#                 index       0
# 0  Barking & Dagenham   60285
# 1              Barnet  122359
# 2              Bexley   80632
# 3               Brent  100692
# 4             Bromley  108286

# %%
df_prices_1998.rename(columns={'index':'Borough', 0:'1998'}, inplace=True)
df_prices_1998.head()
# Out:
#               Borough    1998
# 0  Barking & Dagenham   60285
# 1              Barnet  122359
# 2              Bexley   80632
# 3               Brent  100692
# 4             Bromley  108286

# %%
df_prices_1998_sorted = df_prices_1998.sort_values(by='1998',ascending=False)
df_prices_1998_sorted.head(33)
# Out:
#                  Borough    1998
# 19  Kensington & Chelsea  268350
# 32           Westminster  190531
# 12  Hammersmith & Fulham  175340
# 5                 Camden  170688
# 26  Richmond upon Thames  162956
# 6         City of London  148031
# 18             Islington  134148
# 31            Wandsworth  125406
# 1                 Barnet  122359
# 20  Kingston upon Thames  116399
# 14                Harrow  114778
# 8                 Ealing  111343
# 4                Bromley  108286
# 23                Merton  108049
# 13              Haringey  107419
# 21               Lambeth  103179
# 3                  Brent  100692
# 17              Hounslow   99746
# 16            Hillingdon   97676
# 29         Tower Hamlets   96505
# 25             Redbridge   94514
# 9                Enfield   93030
# 28                Sutton   92087
# 27             Southwark   91405
# 7                Croydon   88143
# 11               Hackney   87869
# 15              Havering   85602
# ...

# %%
ax = df_prices_1998_sorted[['Borough','1998']].plot(kind='bar',ylabel="Housing_prices")
ax.set_xticklabels(df_prices_1998_sorted.Borough)
# Out:
# [Text(0, 0, 'Kensington & Chelsea'),
#  Text(1, 0, 'Westminster'),
#  Text(2, 0, 'Hammersmith & Fulham'),
#  Text(3, 0, 'Camden'),
#  Text(4, 0, 'Richmond upon Thames'),
#  Text(5, 0, 'City of London'),
#  Text(6, 0, 'Islington'),
#  Text(7, 0, 'Wandsworth'),
#  Text(8, 0, 'Barnet'),
#  Text(9, 0, 'Kingston upon Thames'),
#  Text(10, 0, 'Harrow'),
#  Text(11, 0, 'Ealing'),
#  Text(12, 0, 'Bromley'),
#  Text(13, 0, 'Merton'),
#  Text(14, 0, 'Haringey'),
#  Text(15, 0, 'Lambeth'),
#  Text(16, 0, 'Brent'),
#  Text(17, 0, 'Hounslow'),
#  Text(18, 0, 'Hillingdon'),
#  Text(19, 0, 'Tower Hamlets'),
#  Text(20, 0, 'Redbridge'),
#  Text(21, 0, 'Enfield'),
#  Text(22, 0, 'Sutton'),
#  Text(23, 0, 'Southwark'),
#  Text(24, 0, 'Croydon'),
#  Text(25, 0, 'Hackney'),
#  Text(26, 0, 'Havering'),
#  Text(27, 0, 'Greenwich'),
#  Text(28, 0, 'Bexley'),
#  Text(29, 0, 'Waltham Forest'),
#  Text(30, 0, 'Lewisham'),
#  Text(31, 0, 'Newham'),
#  Text(32, 0, 'Barking & Dagenham')]

# %%
top5_average1998 = df_prices_1998_sorted = df_prices_1998.sort_values(by='1998',ascending=False).head(5)
ax = top5_average1998[['Borough','1998']].plot(kind='bar',ylabel="Housing_prices")
ax.set_xticklabels(top5_average1998.Borough)
# Out:
# [Text(0, 0, 'Kensington & Chelsea'),
#  Text(1, 0, 'Westminster'),
#  Text(2, 0, 'Hammersmith & Fulham'),
#  Text(3, 0, 'Camden'),
#  Text(4, 0, 'Richmond upon Thames')]

# %%
# Now, let's explore the average price in 2018.

def Average_price_2018(d):
    y2018 = int(d["Average_price"][d["Year"] == 2018])
    y2018 = [y2018]
    return y2018

prices_2018={}
for b in dfg["London_Borough"].unique():
    borough = dfg[dfg['London_Borough']== b]
    prices_2018[b] = Average_price_2018(borough)

df_prices_2018 = pd.DataFrame(prices_2018)
df_prices_2018.head()
# Out:
#    Barking & Dagenham  Barnet  Bexley   Brent  Bromley  Camden  \
# 0              295196  533266  342603  492845   443409  842410
#
#    City of London  Croydon  Ealing  Enfield  ...  Merton  Newham  Redbridge  \
# 0          784808   370298  480050   396631  ...  512293  359022     422591
#
#    Richmond upon Thames  Southwark  Sutton  Tower Hamlets  Waltham Forest  \
# 0                652665     504235  379262         446500          440859
#
#    Wandsworth  Westminster
# 0      596649      1020025
#
# [1 rows x 33 columns]

# %%
df_prices_2018_T = df_prices_2018.T
df_prices_2018 = df_prices_2018_T.reset_index()
df_prices_2018.head()
# Out:
#                 index       0
# 0  Barking & Dagenham  295196
# 1              Barnet  533266
# 2              Bexley  342603
# 3               Brent  492845
# 4             Bromley  443409

# %%
df_prices_2018.rename(columns={'index':'Borough', 0:'2018'}, inplace=True)
df_prices_2018.head()
# Out:
#               Borough    2018
# 0  Barking & Dagenham  295196
# 1              Barnet  533266
# 2              Bexley  342603
# 3               Brent  492845
# 4             Bromley  443409

# %%
df_prices_2018_sorted = df_prices_2018.sort_values(by='2018',ascending=False)
df_prices_2018_sorted.head(33)
# Out:
#                  Borough     2018
# 19  Kensington & Chelsea  1363880
# 32           Westminster  1020025
# 5                 Camden   842410
# 6         City of London   784808
# 12  Hammersmith & Fulham   725525
# 26  Richmond upon Thames   652665
# 18             Islington   649824
# 31            Wandsworth   596649
# 13              Haringey   551560
# 11               Hackney   544640
# 1                 Barnet   533266
# 23                Merton   512293
# 21               Lambeth   511536
# 27             Southwark   504235
# 20  Kingston upon Thames   497090
# 3                  Brent   492845
# 8                 Ealing   480050
# 14                Harrow   465907
# 29         Tower Hamlets   446500
# 4                Bromley   443409
# 30        Waltham Forest   440859
# 25             Redbridge   422591
# 22              Lewisham   411628
# 16            Hillingdon   410266
# 17              Hounslow   396631
# 9                Enfield   396631
# ...

# %%
ax = df_prices_2018_sorted[['Borough','2018']].plot(kind='bar',ylabel="Housing_prices")
ax.set_xticklabels(df_prices_2018_sorted.Borough)
# Out:
# [Text(0, 0, 'Kensington & Chelsea'),
#  Text(1, 0, 'Westminster'),
#  Text(2, 0, 'Camden'),
#  Text(3, 0, 'City of London'),
#  Text(4, 0, 'Hammersmith & Fulham'),
#  Text(5, 0, 'Richmond upon Thames'),
#  Text(6, 0, 'Islington'),
#  Text(7, 0, 'Wandsworth'),
#  Text(8, 0, 'Haringey'),
#  Text(9, 0, 'Hackney'),
#  Text(10, 0, 'Barnet'),
#  Text(11, 0, 'Merton'),
#  Text(12, 0, 'Lambeth'),
#  Text(13, 0, 'Southwark'),
#  Text(14, 0, 'Kingston upon Thames'),
#  Text(15, 0, 'Brent'),
#  Text(16, 0, 'Ealing'),
#  Text(17, 0, 'Harrow'),
#  Text(18, 0, 'Tower Hamlets'),
#  Text(19, 0, 'Bromley'),
#  Text(20, 0, 'Waltham Forest'),
#  Text(21, 0, 'Redbridge'),
#  Text(22, 0, 'Lewisham'),
#  Text(23, 0, 'Hillingdon'),
#  Text(24, 0, 'Hounslow'),
#  Text(25, 0, 'Enfield'),
#  Text(26, 0, 'Greenwich'),
#  Text(27, 0, 'Sutton'),
#  Text(28, 0, 'Croydon'),
#  Text(29, 0, 'Havering'),
#  Text(30, 0, 'Newham'),
#  Text(31, 0, 'Bexley'),
#  Text(32, 0, 'Barking & Dagenham')]

# %%
top5_average = df_prices_2018_sorted = df_prices_2018.sort_values(by='2018',ascending=False).head(5)
ax = top5_average[['Borough','2018']].plot(kind='bar',ylabel="Housing_prices")
ax.set_xticklabels(top5_average.Borough)
# Out:
# [Text(0, 0, 'Kensington & Chelsea'),
#  Text(1, 0, 'Westminster'),
#  Text(2, 0, 'Camden'),
#  Text(3, 0, 'City of London'),
#  Text(4, 0, 'Hammersmith & Fulham')]

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!
#
# ### Which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?
#
# Hackney has seen the greatest increase in housing prices from 1998 to 2018 with an increase of ~620%.
#
# Why Hackney? In terms of affordability, in 1998, Hackney was inexpensive in comparision to surrounding boroughs. Furthermore, its proximity and ease of acces to the City of London is a factor of its increasing attractiveness and demand. Furthermore, while not demonstrated by this data, it is said "Hackney has created a reputation as one of the “coolest” places to live in London. The area has emerged as the heart of music, youth culture and creativity in the capital." (https://goodmove.org.uk/living-in-hackney/)
#
# Here is a list of the top five borough and their respective increase:
#
#     1        Hackney   6.198286 - 619.83 % increase
#     2        Waltham Forest   5.834756 - 583.48 % increase
#     3        Southwark   5.516485 - 551.65 % increase
#     4        Lewisham   5.449221 - 544.92 % increase
#     5        Westminster   5.353565 - 535.36 % increase
